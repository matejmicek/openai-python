# %% [markdown]
# # 3. Train a fine-tuning model specialized for Q&A
# This notebook will utilize the dataset of context, question and answer pairs to additionally create adversarial questions and context pairs, where the question was not generated on that context. In those cases the model will be prompted to answer "No sufficient context for answering the question". We will also train a discriminator model, which predicts whether the question can be answered based on the context or not.
#
# We will add hard adversarial examples as well, which will be based either on semantically similar sections, or neighbouring sections, originating from the same article.

# %%
import openai
import pandas as pd



openai.api_key ='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'

df = pd.read_csv('deloitte_qa.csv')
olympics_search_fileid = "file-YwQzzozDj4JLtYIU3cqryyBv"
df.head()
# Out:
#                                                 text  \
# 0  “Technologies that are easy to understand and ...
# 1  Milan Kulhánek is a Partner in the Consulting ...
# 2  “Technologies that are easy to understand and ...
# 3  For companies that want to use full potential ...
# 4  Tax authorities require the taxpayers to prove...
#
#                                              context  \
# 0  “Technologies that are easy to understand and ...
# 1  Milan Kulhánek is a Partner in the Consulting ...
# 2  “Technologies that are easy to understand and ...
# 3  For companies that want to use full potential ...
# 4  Tax authorities require the taxpayers to prove...
#
#                                            questions  \
# 0  1. What technologies does Pavel Šiška believe ...
# 1  1. What is Milan Kulhánek's role at Deloitte C...
# 2  1. What technologies does Pavel Šiška believe ...
# 3  1. What services does the company offer to sup...
# 4  1. What do tax authorities require of taxpayer...
#
#                                              answers
# 0  1. Pavel Šiška believes that technologies that...
# 1  1. Milan Kulhánek is a Partner in the Consulti...
# 2  1. Technologies that are easy to understand an...
# 3  1. The company offers a broad range of service...
# 4  1. Tax authorities require taxpayers to prove ...

# %% [markdown]
# Split the sections into a training and testing set

# %%
df['title'] = df.context

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.1, random_state=42)
len(train_df), len(test_df)
# Out:
# (42, 5)

# %%
df
# Out:
#                                                  text  \
# 0   “Technologies that are easy to understand and ...
# 1   Milan Kulhánek is a Partner in the Consulting ...
# 2   “Technologies that are easy to understand and ...
# 3   For companies that want to use full potential ...
# 4   Tax authorities require the taxpayers to prove...
# 5   \n   Tomáš Babáček is a partner in the Regulat...
# 6   Working with Deloitte Private means you will w...
# 7   It is ever more typical nowadays for business ...
# 8   Risk management tools consolidate a large numb...
# 9   It does not happen just in the Czech Republic ...
# 10  “Our role, in partnership with the ABSL, will ...
# 11  The typical finding is the usage of incorrect ...
# 12  Deloitte is the only professional services fir...
# 13  Our survey has shown that more than a half of ...
# 14  Over the past few years, the technology landsc...
# 15  Tervel is a Director in the Analytics & Inform...
# 16  Reviewing business partners on a one-off basis...
# 17  Through cooperation with the client, we conduc...
# 18  \n   Jakub Sova is a partner at Deloitte respo...
# 19  Innovation is one area in which many family bu...
# 20  Jakub Sova is a partner at Deloitte responsibl...
# 21  Starting in January 2017, Deloitte enters into...
# 22  We provide our clients with extensive experien...
# 23  What is a cookie?\nA cookie is a small text fi...
# 24  Just like any other company, family-owned comp...
# 25  Marek is a Partner in the Consulting function ...
# 26  Thanks to Deloitte’s partnership with IXPERTA ...
# 27  Jaroslav (Jarek) Skvrna currently serves as th...
# 28  \n   Petr is the partner leading the Deloitte ...
# 29  While liquidity and financial risk management ...
# 30  \n   Milan Kulhánek is a Partner in the Consul...
# 31  Scenario 2 projects a different future marked ...
# 32  Biggest impact to be expected in retail bankin...
# 33  Car as a Platform sales are expected to increa...
# 34  \n   Jaroslava Kračúnová is a partner and head...
# 35  For companies that want to use full potential ...
# 36  Companies in difficulty often find themselves ...
# 37  European Powers of Construction (EPoC) is an a...
# 38  We have provided advisory and brokerage servic...
# 39  Taking your organization somewhere it’s never ...
# 40  Harnessing the power of technologies requires ...
# 41  As Oracle’s first Global Cloud Elite partner, ...
# 42  The use of tariff preferences in the import of...
# 43  We perform data analyses based on comprehensiv...
# 44  Today, I am a partner at Deloitte LLP in Londo...
# 45  A Czech company had been on the market for alm...
# 46  Winning a single award doesn’t say much, but w...
#
#                                               context  \
# 0   “Technologies that are easy to understand and ...
# 1   Milan Kulhánek is a Partner in the Consulting ...
# 2   “Technologies that are easy to understand and ...
# 3   For companies that want to use full potential ...
# 4   Tax authorities require the taxpayers to prove...
# 5   \n   Tomáš Babáček is a partner in the Regulat...
# 6   Working with Deloitte Private means you will w...
# 7   It is ever more typical nowadays for business ...
# 8   Risk management tools consolidate a large numb...
# 9   It does not happen just in the Czech Republic ...
# 10  “Our role, in partnership with the ABSL, will ...
# 11  The typical finding is the usage of incorrect ...
# 12  Deloitte is the only professional services fir...
# 13  Our survey has shown that more than a half of ...
# 14  Over the past few years, the technology landsc...
# 15  Tervel is a Director in the Analytics & Inform...
# 16  Reviewing business partners on a one-off basis...
# 17  Through cooperation with the client, we conduc...
# 18  \n   Jakub Sova is a partner at Deloitte respo...
# 19  Innovation is one area in which many family bu...
# 20  Jakub Sova is a partner at Deloitte responsibl...
# 21  Starting in January 2017, Deloitte enters into...
# 22  We provide our clients with extensive experien...
# 23  What is a cookie?\nA cookie is a small text fi...
# 24  Just like any other company, family-owned comp...
# 25  Marek is a Partner in the Consulting function ...
# 26  Thanks to Deloitte’s partnership with IXPERTA ...
# 27  Jaroslav (Jarek) Skvrna currently serves as th...
# 28  \n   Petr is the partner leading the Deloitte ...
# 29  While liquidity and financial risk management ...
# 30  \n   Milan Kulhánek is a Partner in the Consul...
# 31  Scenario 2 projects a different future marked ...
# 32  Biggest impact to be expected in retail bankin...
# 33  Car as a Platform sales are expected to increa...
# 34  \n   Jaroslava Kračúnová is a partner and head...
# 35  For companies that want to use full potential ...
# 36  Companies in difficulty often find themselves ...
# 37  European Powers of Construction (EPoC) is an a...
# 38  We have provided advisory and brokerage servic...
# 39  Taking your organization somewhere it’s never ...
# 40  Harnessing the power of technologies requires ...
# 41  As Oracle’s first Global Cloud Elite partner, ...
# 42  The use of tariff preferences in the import of...
# 43  We perform data analyses based on comprehensiv...
# 44  Today, I am a partner at Deloitte LLP in Londo...
# 45  A Czech company had been on the market for alm...
# 46  Winning a single award doesn’t say much, but w...
#
#                                             questions  \
# 0   1. What technologies does Pavel Šiška believe ...
# 1   1. What is Milan Kulhánek's role at Deloitte C...
# 2   1. What technologies does Pavel Šiška believe ...
# 3   1. What services does the company offer to sup...
# 4   1. What do tax authorities require of taxpayer...
# 5   1. What is Tomáš Babáček's job title?\n2. What...
# 6   1. What are the benefits of working with a tru...
# 7   1. What are some of the benefits of an interna...
# 8   1. What are some of the benefits of using risk...
# 9   1. What is the main issue discussed in the tex...
# 10  1. What is Deloitte's role in partnership with...
# 11  1. What is the typical finding in regards to V...
# 12  1. What can Deloitte advise corporate buyers a...
# 13  1. What does the survey say about companies an...
# 14  1. What is The Cloud?\n2. What are the applica...
# 15  1. What is Tervel's role at Deloitte Czech Rep...
# 16  1. What is the name of Deloitte's new applicat...
# 17  1. What is the main purpose of the company?\n2...
# 18  1. What is Jakub Sova's role at Deloitte?\n2. ...
# 19  1. What is one area in which many family busin...
# 20  1. What is Jakub Sova's role at Deloitte?\n2. ...
# 21  1. What is the strategic partnership between D...
# 22  1. What kind of experience does Deloitte's Pra...
# 23  1. What is a cookie?\n2. What are the differen...
# 24  1. What are some of the goals that family-owne...
# 25  1. What is Marek's role at Deloitte?\n2. What ...
# 26  1. What specific requirements does Deloitte's ...
# 27  1. What position did Jaroslav Skvrna assume on...
# 28  1. What is Petr's role at Deloitte Digital?\n2...
# 29  1. What are the top two chief financial office...
# 30  1. What is Milan Kulhánek's role at Deloitte C...
# 31  1. What is the main difference between Scenari...
# 32  1. What is the biggest impact that CEE banks e...
# 33  1. What is the main role of connectivity for C...
# 34  1. What is Jaroslava Kračúnová's role at Deloi...
# 35  1. What services does the company offer to sup...
# 36  1. What are some of the things that a company ...
# 37  1. What is EPoC?\n2. What is the purpose of EP...
# 38  1. What services did the advisory company prov...
# 39  1. What does it mean to be Oracle's first Glob...
# 40  1. What are some of the complex system integra...
# 41  1. What are some of the benefits of working wi...
# 42  1. What is the main idea of the text?\n2. What...
# 43  1. What data do we use for our analyses?\n2. W...
# 44  1. What is the author's current occupation?\n2...
# 45  1. What was the Czech company's business partn...
# 46  1. What does it mean if an organization wins m...
#
#                                               answers  \
# 0   1. Pavel Šiška believes that technologies that...
# 1   1. Milan Kulhánek is a Partner in the Consulti...
# 2   1. Technologies that are easy to understand an...
# 3   1. The company offers a broad range of service...
# 4   1. Tax authorities require taxpayers to prove ...
# 5   1. Tomáš Babáček is a partner in the Regulator...
# 6   1. The benefits of working with a trusted advi...
# 7   1. Some of the benefits of an international bu...
# 8   1. Risk management tools can help reduce unnec...
# 9   1. The main issue discussed in the text is tax...
# 10  1. Deloitte's role in partnership with the ABS...
# 11  1. The typical finding is the usage of incorre...
# 12  1. Deloitte can advise corporate buyers and pr...
# 13  1. The survey says that more than a half of al...
# 14  1. The Cloud is a network of servers that allo...
# 15  1. Tervel is a Director in the Analytics & Inf...
# 16  1. The name of Deloitte's new application is M...
# 17  1. The main purpose of the company is to condu...
# 18  1. Jakub Sova is a partner at Deloitte respons...
# 19  1. Innovation is one area in which many family...
# 20  1. Jakub Sova is a partner at Deloitte respons...
# 21  1. The strategic partnership between Deloitte ...
# 22  1. Deloitte's Prague office has extensive expe...
# 23  1. A cookie is a small text file placed on you...
# 24  1. Family-owned companies may be looking for s...
# 25  1. Marek is a Partner in the Consulting functi...
# 26  1. Deloitte's partnership with IXPERTA support...
# 27  1. Jaroslav Skvrna assumed the position of Chi...
# 28  1. Petr is the partner leading the Deloitte Di...
# 29  1. The top two chief financial officer (CFO) m...
# 30  1. Milan Kulhánek is a Partner in the Consulti...
# 31  1. The main difference between Scenario 2 and ...
# 32  1. The biggest impact that CEE banks expect fr...
# 33  1. The main role of connectivity for Car as a ...
# 34  1. Jaroslava Kračúnová is a partner and head o...
# 35  1. The company offers services to support clie...
# 36  1. A company in difficulty may have to do thin...
# 37  1. EPoC is an annual publication produced by D...
# 38  1. The advisory company provided advisory and ...
# 39  1. Oracle's first Global Cloud Elite partner i...
# 40  1. Complex system integration challenges busin...
# 41  1. Some of the benefits of working with Deloit...
# 42  1. The main idea of the text is that incorrect...
# 43  1. We use data on import and export concerning...
# 44  1. The author is a partner at Deloitte LLP in ...
# 45  1. The Czech company's business partner offere...
# 46  1. It means that the organization is consisten...
#
#                                                 title
# 0   “Technologies that are easy to understand and ...
# 1   Milan Kulhánek is a Partner in the Consulting ...
# 2   “Technologies that are easy to understand and ...
# 3   For companies that want to use full potential ...
# 4   Tax authorities require the taxpayers to prove...
# 5   \n   Tomáš Babáček is a partner in the Regulat...
# 6   Working with Deloitte Private means you will w...
# 7   It is ever more typical nowadays for business ...
# 8   Risk management tools consolidate a large numb...
# 9   It does not happen just in the Czech Republic ...
# 10  “Our role, in partnership with the ABSL, will ...
# 11  The typical finding is the usage of incorrect ...
# 12  Deloitte is the only professional services fir...
# 13  Our survey has shown that more than a half of ...
# 14  Over the past few years, the technology landsc...
# 15  Tervel is a Director in the Analytics & Inform...
# 16  Reviewing business partners on a one-off basis...
# 17  Through cooperation with the client, we conduc...
# 18  \n   Jakub Sova is a partner at Deloitte respo...
# 19  Innovation is one area in which many family bu...
# 20  Jakub Sova is a partner at Deloitte responsibl...
# 21  Starting in January 2017, Deloitte enters into...
# 22  We provide our clients with extensive experien...
# 23  What is a cookie?\nA cookie is a small text fi...
# 24  Just like any other company, family-owned comp...
# 25  Marek is a Partner in the Consulting function ...
# 26  Thanks to Deloitte’s partnership with IXPERTA ...
# 27  Jaroslav (Jarek) Skvrna currently serves as th...
# 28  \n   Petr is the partner leading the Deloitte ...
# 29  While liquidity and financial risk management ...
# 30  \n   Milan Kulhánek is a Partner in the Consul...
# 31  Scenario 2 projects a different future marked ...
# 32  Biggest impact to be expected in retail bankin...
# 33  Car as a Platform sales are expected to increa...
# 34  \n   Jaroslava Kračúnová is a partner and head...
# 35  For companies that want to use full potential ...
# 36  Companies in difficulty often find themselves ...
# 37  European Powers of Construction (EPoC) is an a...
# 38  We have provided advisory and brokerage servic...
# 39  Taking your organization somewhere it’s never ...
# 40  Harnessing the power of technologies requires ...
# 41  As Oracle’s first Global Cloud Elite partner, ...
# 42  The use of tariff preferences in the import of...
# 43  We perform data analyses based on comprehensiv...
# 44  Today, I am a partner at Deloitte LLP in Londo...
# 45  A Czech company had been on the market for alm...
# 46  Winning a single award doesn’t say much, but w...

# %% [markdown]
# we check that he separator we intend to use isn't present within the contexts

# %% [markdown]
# ## 3.1 Create the fine-tuning datasets for Q&A and discriminator models
# The fine-tuning dataset is created in the following way. For every corresponding question, answer and context pair we create:
# - Positive example: correct question, answer, context pair
# - Negative examples:
#   - random negative example, where the random context is paired with the question
#   - two hard negative examples
#     - one originating from the same wikipedia article
#     - another, which is most similar to the correct context
#
# This process is noisy, as sometimes the question might be answerable given a different context, but on average we hope this won't affect the peformance too much.
#
# We apply the same process of dataset creation for both the discriminator, and the Q&A answering model. We apply the process separately for the training and testing set, to ensure that the examples from the traing set don't feature within the test set.

# %%
import random

def get_random_similar_contexts(question, context, file_id=olympics_search_fileid, search_model='ada', max_rerank=10):
    """
    Find similar contexts to the given context using the search file
    """
    try:
        results = openai.Engine(search_model).search(
            search_model=search_model, 
            query=question, 
            max_rerank=max_rerank,
            file=file_id
        )
        candidates = []
        for result in results['data'][:3]:
            if result['text'] == context:
                continue
            candidates.append(result['text'])
        random_candidate = random.choice(candidates)
        return random_candidate
    except Exception as e:
        print(e)
        return ""

def create_fine_tuning_dataset(df, discriminator=False, n_negative=1, add_related=False):
    """
    Create a dataset for fine tuning the OpenAI model; either for a discriminator model, 
    or a model specializing in Q&A, where it says if no relevant context is found.

    Parameters
    ----------
    df: pd.DataFrame
        The dataframe containing the question, answer and context pairs
    discriminator: bool
        Whether to create a dataset for the discriminator
    n_negative: int
        The number of random negative samples to add (using a random context)
    add_related: bool
        Whether to add the related contexts to the correct context. These are hard negative examples

    Returns
    -------
    pd.DataFrame
        The dataframe containing the prompts and completions, ready for fine-tuning
    """
    rows = []
    for i, row in df.iterrows():
        for q, a in zip(("1." + row.questions).split('\n'), ("1." + row.answers).split('\n')):
            if len(q) >10 and len(a) >10:
                if discriminator:
                    rows.append({"prompt":f"{row.context}\nQuestion: {q[2:].strip()}\n Related:", "completion":f" yes"})
                else:
                    rows.append({"prompt":f"{row.context}\nQuestion: {q[2:].strip()}\nAnswer:", "completion":f" {a[2:].strip()}"})

    for i, row in df.iterrows():
        for q in ("1." + row.questions).split('\n'):
            if len(q) >10:
                for j in range(n_negative + (2 if add_related else 0)):
                    random_context = ""
                    if j == 0 and add_related:
                        # add the related contexts based on originating from the same wikipedia page
                        subset = df[(df.title == row.title) & (df.context != row.context)]
                        
                        if len(subset) < 1:
                            continue
                        random_context = subset.sample(1).iloc[0].context
                    if j == 1 and add_related:
                        # add the related contexts based on the most similar contexts according to the search
                        random_context = get_random_similar_contexts(q[2:].strip(), row.context, search_model='ada', max_rerank=10)
                    else:
                        while True:
                            # add random context, which isn't the correct context
                            random_context = df.sample(1).iloc[0].context
                            if random_context != row.context:
                                break
                    if discriminator:
                        rows.append({"prompt":f"{random_context}\nQuestion: {q[2:].strip()}\n Related:", "completion":f" no"})
                    else:
                        rows.append({"prompt":f"{random_context}\nQuestion: {q[2:].strip()}\nAnswer:", "completion":f" No appropriate context found to answer the question."})

    return pd.DataFrame(rows)

# %% [markdown]
# We apply the same process of dataset creation for both the discriminator, and the Q&A answering model. We apply the process separately for the training and testing set, to ensure that the examples from the traing set don't feature within the test set.

# %%
for name, is_disc in [('discriminator', True), ('qa', False)]:
    for train_test, dt in [('train', train_df), ('test', test_df)]:
        ft = create_fine_tuning_dataset(dt, discriminator=is_disc, n_negative=1, add_related=True)
        ft.to_json(f'{name}_{train_test}.jsonl', orient='records', lines=True)
# Out:
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 64.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 64.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 64.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 68.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 72.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 68.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 76.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 80.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 84.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 72.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 88.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 92.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 96.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 64.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 76.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 100.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 68.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 76.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 104.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 72.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 68.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 80.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 104.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 76.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 72.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 84.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 108.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 80.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 88.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 112.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 84.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 72.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 88.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 116.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 88.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 92.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 112.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 92.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 76.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 96.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 72.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 96.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 116.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 100.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 96.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 120.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 104.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 100.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 124.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 72.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 108.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 104.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 128.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 108.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 132.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 108.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 136.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 76.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 112.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 108.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 136.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 80.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 116.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 112.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 140.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 112.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 116.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 144.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 84.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 116.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 120.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 148.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 88.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 148.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 92.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 120.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 124.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 152.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 96.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 124.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 128.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 156.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 92.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 128.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 132.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 96.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 132.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 160.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 100.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 136.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 136.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 160.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 104.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 140.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 140.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 164.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 144.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 168.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 104.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 148.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 144.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 172.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 152.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 176.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 108.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 156.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 148.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 180.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 112.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 160.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 152.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 116.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 156.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 180.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 120.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 164.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 160.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 184.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 124.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 168.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 164.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 188.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 168.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 168.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 172.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 172.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 128.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 176.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 176.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 188.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 176.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 192.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 132.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 180.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 196.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 184.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# ...
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 272.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 264.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 212.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 284.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 268.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 288.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 268.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 272.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 216.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 292.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 272.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 220.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 296.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 276.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 300.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 272.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 280.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 304.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 276.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 284.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 224.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 280.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 288.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 228.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 284.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 292.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 228.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 300.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 288.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 296.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 304.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 232.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 308.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 292.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 300.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 312.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 296.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 236.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 312.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 304.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 240.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 316.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 296.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 236.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.
# Rate limit reached for default in organization org-uTbKXOI3BONOsvlv80LDu7Rn on requests per min. Limit: 60.000000 / min. Current: 320.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.

# %% [markdown]
# We formatted the data according to the recommendations from the fine-tuning tool, which is available using
# > openai tools fine_tunes.prepare_data -f qa_train.jsonl
#
# We highly recommend that you use this tool, which suggests improvements in your data formatting for fine-tuning.

# %% [markdown]
# ## 3.2 Submit the datasets for fine-tuning

# %%
import sys

# %%
# !pip3 install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (0.20.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai) (4.63.0)
# Requirement already satisfied: pandas>=1.2.3 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from openai) (1.4.2)
# Requirement already satisfied: pandas-stubs>=1.1.0.11 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from openai) (1.4.3.220703)
# Requirement already satisfied: openpyxl>=3.0.7 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from openai) (3.0.10)
# Requirement already satisfied: requests>=2.20 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from openai) (2.28.1)
# Requirement already satisfied: et-xmlfile in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from openpyxl>=3.0.7->openai) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2.3->openai) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2.3->openai) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2.3->openai) (1.22.4)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.3->openai) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->openai) (1.26.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/matejmicek/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->openai) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai) (2021.10.8)
# WARNING: You are using pip version 21.2.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
openai.FineTune.create({t:})
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /var/folders/5k/x7jyjp5s6_750_cnc1l6ljtr0000gn/T/ipykernel_17923/2642857257.py in <module>
# ----> 1 openai.FineTune.create()
#
# ~/Library/Python/3.7/lib/python/site-packages/openai/api_resources/abstract/createable_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#      36
#      37         response, _, api_key = requestor.request(
# ---> 38             "post", url, params, request_id=request_id
#      39         )
#      40
#
# ~/Library/Python/3.7/lib/python/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id)
#     120             request_id=request_id,
#     121         )
# --> 122         resp, got_stream = self._interpret_response(result, stream)
#     123         return resp, got_stream, self.api_key
#     124
#
# ~/Library/Python/3.7/lib/python/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     328             return (
#     329                 self._interpret_response_line(
# --> 330                     result.content, result.status_code, result.headers, stream=False
#     331                 ),
#     332                 False,
#
# ~/Library/Python/3.7/lib/python/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     361         if stream_error or not 200 <= rcode < 300:
#     362             raise self.handle_error_response(
# --> 363                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     364             )
#     365         return resp
#
# InvalidRequestError: You submitted a length-0 POST body, but must submit a JSON object. (HINT: Try submitting an empty object instead, i.e. {}. If you're using curl, you can pass -d '{}' -H 'Content-Type: application/json')

# %%
# !openai api fine_tunes.create -t "discriminator_train.jsonl" -v "discriminator_test.jsonl" --batch_size 16  --compute_classification_metrics --classification_positive_class " yes" --model ada
# Out:
# zsh:1: command not found: openai

# %% [markdown]
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-07-04 17:45:14] Created fine-tune: ft-QDmUoNr3Sp3l5X5XjyFLkRlK
# [2022-07-04 17:45:24] Fine-tune costs $0.09
# [2022-07-04 17:45:24] Fine-tune enqueued. Queue number: 0
# [2022-07-04 17:45:29] Fine-tune started
# [2022-07-04 17:46:03] Completed epoch 1/4
# [2022-07-04 17:46:19] Completed epoch 2/4
# [2022-07-04 17:46:33] Completed epoch 3/4
# [2022-07-04 17:46:46] Completed epoch 4/4
# [2022-07-04 17:47:08] Uploaded model: ada:ft-personal-2022-07-04-15-47-06
# [2022-07-04 17:47:10] Uploaded result file: file-bBQKc6u4S3qOAGmByA5CWnUx
# [2022-07-04 17:47:11] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m ada:ft-personal-2022-07-04-15-47-06 -p <YOUR_PROMPT>

# %%
# !openai api fine_tunes.create -t "qa_train.jsonl" -v "qa_test.jsonl" --batch_size 16
# Out:
# zsh:1: command not found: openai

# %% [markdown]
# ## 3.3 Using the fine-tuned models
#
# We will now use the fine-tuned discriminator and the fine-tuned Q&A model. By requesting logprobs, we can see how certain the discriminator is in a `yes` vs `no` answer.

# %%
ft_discriminator = "ada:ft-personal-2022-07-04-15-47-06"
ft_qa = "curie:ft-personal-2022-07-04-15-50-49"

def apply_ft_discriminator(context, question, discriminator_model):
    """
    Apply the fine tuned discriminator to a question, to assess whether it can be answered from the context.
    """
    prompt = f"{context}\nQuestion: {question}\n Related:"
    result = openai.Completion.create(model=discriminator_model, prompt=prompt, max_tokens=1, temperature=0, top_p=1, n=1, logprobs=2)
    return result['choices'][0]['logprobs']['top_logprobs']

apply_ft_discriminator('The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957.', 
                        'What was the first human-made object in space?', ft_discriminator)
# Out:
# [<OpenAIObject at 0x7f96188fc710> JSON: {
#    " no": -2.2787914,
#    " yes": -0.10880088
#  }]

# %% [markdown]
# We can see that the model can generalize well to different contexts and questions.

# %%
QUESTION = 'Who is the partner for consulting in Deloitte?'

def apply_ft_qa_answer(context, question, answering_model):
    """
    Apply the fine tuned discriminator to a question
    """
    prompt = f"{context}\nQuestion: {question}\nAnswer:"
    result = openai.Completion.create(model=answering_model, prompt=prompt, max_tokens=30, temperature=0, top_p=1, n=1, stop=['.','\n'])
    return result['choices'][0]['text']

apply_ft_qa_answer('There are many partners in Deloitte, for example Jan Siska is the partner for Consulting.', 
                    QUESTION, ft_qa)
# Out:
# ' No appropriate context found to answer the question'

# %% [markdown]
# We can see that the model can answer the question, when the context is appropriate.

# %%
apply_ft_qa_answer('The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957.',
                    'What is impressive about the Soviet Union?', ft_qa)
# Out:
# ' The Soviet Union was the first country to successfully launch a satellite into space'

# %%
apply_ft_qa_answer('The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957.',
                    'How many cars were produced in the Soviet Union in 1970?', ft_qa)
# Out:
# ' No appropriate context found to answer the question'

# %% [markdown]
# We can see that the model knows when to answer the question, and when to say that insufficient context is present to answer the question.

# %% [markdown]
# We can also combine a discriminator and a base model, or a fine-tuned Q&A model. Discriminator can essentially serve as a decision whether the question can be answered given the context or not.

# %%
def answer_question_conditionally(answering_model, discriminator_model, context, question, discriminator_logprob_yes_modifier=0):
    logprobs = apply_ft_discriminator(context, question, discriminator_model)
    yes_logprob = logprobs[' yes'] if ' yes' in logprobs else -100
    no_logprob = logprobs[' no'] if ' no' in logprobs else -100
    if yes_logprob + discriminator_logprob_yes_modifier < no_logprob:
        return " No appropriate context found to answer the question based on the discriminator."
    return apply_ft_qa_answer(context, question, answering_model)
answer_question_conditionally(ft_qa, ft_discriminator, 
                                "Crowdless games are a rare although not unheard-of occurrence in sports. \
                                 When they do occur, it is usually the result of events beyond the control \
                                 of the teams or fans, such as weather-related concerns, public health concerns, \
                                 or wider civil disturbances unrelated to the game. For instance, \
                                 the COVID-19 pandemic caused many sports leagues around the world \
                                 to be played behind closed doors.",
                                "Could weather cause a sport event to have no crowd?")
# Out:
# ' No'

# %% [markdown]
# The above function illustrates how to potentially combine a discriminator and a fine-tuned Q&A model. This gives a more fine-grained control over how certain we want the model to be before it answers the question.
#
# We'll now take a look on how answers endpoint works - combining search to retrieve the relevant context from a knowledge base, and then using the fine-tuned Q&A model to answer the question.

# %% [markdown]
# ## 3.4 Answering the question based on a knowledge base
# Finally we can use a logic similar to the [/answers](https://beta.openai.com/docs/api-reference/answers) endpoint, where we first search for the relevant context, and then ask a Q&A model to answer the question given that context. If you'd like to see the implementation details, check out the [`answers_with_ft.py`](answers_with_ft.py) file.

# %%
QUESTION = 'Who is the partner in the Regulatory & Compliance department at Deloitte Legal in Prague?'



from answers_with_ft import answer_question
answer_question(olympics_search_fileid, ft_qa, QUESTION)
# Out:
# ' Tomáš Babáček is a partner in the Regulatory & Compliance department at Deloitte Legal in Prague'

# %%
ft_qa
# Out:
# 'curie:ft-personal-2022-07-04-15-50-49'

# %%
import os
import openai
openai.api_key ='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'
openai.Answer.create(
  search_model="ada",
  model="curie",
  question='Who is the partner in the Regulatory & Compliance department at Deloitte Legal in Prague',
  documents=["Puppy A is happy.", "Puppy B is sad."],
  examples_context="In 2017, U.S. life expectancy was 78.6 years.",
  examples=[["What is human life expectancy in the United States?","78 years."]],
  max_tokens=5,
  stop=["\n", "<|endoftext|>"],
)
